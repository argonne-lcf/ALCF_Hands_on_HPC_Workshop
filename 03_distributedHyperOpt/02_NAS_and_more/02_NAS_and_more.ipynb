# %% [markdown]
# <img src="Figures/Deephyper.png" style="height: 200px;">
#
# <h1><center>From Neural Architecture Search to Automated Deep Ensemble with Uncertainty Quantification</center></h1>
#
# ## Table of Contents
#
# 1. [Imports and GPU Detection](#imports-and-gpu-detection)
# 2. [Start Ray](#Start-Ray)
# 3. [A Synthetic Dataset](#a-synthetic-dataset)
# 4. [Scaling the Data](#scaling-the-data)
# 5. [Baseline Neural Network](#baseline-neural-network)
# 6. [Define the Neural Architecture Search Space](#define-the-neural-architecture-search-space)
# 7. [Define the Neural Architecture Search Optimization Problem](#define-the-neural-architecture-search-optimization-problem)
# 8. [Define the Evaluator Object](#Define-the-Evaluator-Object)
# 9. [Define and Run the Neural Architecture Search](#Define-and-Run-the-Neural-Architecture-Search)
# 10. [Adding Uncertainty Quantification to the Baseline Neural Network](#Adding-Uncertainty-Quantification-to-the-Baseline-Neural-Network)
# 11. [Ensemble of Reural Networks With Random Initialization](#Ensemble-of-Reural-Networks-With-Random-Initialization)
# 12. [AutoDEUQ: Automated Deep Ensemble with Uncertainty Quantification](#AutoDEUQ:-Automated-Deep-Ensemble-with-Uncertainty-Quantification)
#
# ## Imports and GPU Detection <a class="anchor" id="imports-and-gpu-detection"></a>
#
# <div class="alert alert-warning">
#
# <b>Warning</b>
#
# By design asyncio does not allow nested event loops. Jupyter is using Tornado which already starts an event loop. Therefore the following patch is required to run this tutorial.
#
# </div>

# %%
# !pip install nest_asyncio

import nest_asyncio
nest_asyncio.apply()
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nest_asyncio in /lus/theta-fs0/software/thetagpu/conda/2021-09-22/mconda3/lib/python3.8/site-packages (1.5.1)

# %%
import json
import os
import pathlib
import shutil

# !export TF_CPP_MIN_LOG_LEVEL=3
# !export TF_XLA_FLAGS=--tf_xla_enable_xla_devices

import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tqdm import tqdm

# %% [markdown]
# <div class="alert alert-info">
#
# <b>Note</b>
#
# The `TF_CPP_MIN_LOG_LEVEL` can be used to avoid the logging of Tensorflow *DEBUG*, *INFO* and *WARNING* statements.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
#
# <b>Note</b>
#
# The following can be used to detect if **GPU** devices are available on the current host.
#
# </div>

# %%
available_gpus = tf.config.list_physical_devices("GPU")
n_gpus = len(available_gpus)
if n_gpus > 1:
    n_gpus -= 1
is_gpu_available = n_gpus > 0

if is_gpu_available:
    print(f"{n_gpus} GPU{'s are' if n_gpus > 1 else ' is'} available.")
else:
    print("No GPU available")
# Out:
# 7 GPUs are available.

# %% [markdown]
# ## Start Ray
#
# We launch the Ray run-time depending on the detected local ressources. If GPU(s) is(are) detected then 1 worker is started for each GPU. If not, then only 1 worker is started. You can start more workers by setting `num_cpus=1` to a value greater than 1.
#
# <div class="alert alert-warning">
#
# <b>Warning</b>
#
# In the case of GPUs it is important to follow this scheme to avoid multiple processes (Ray workers vs current process) to lock the same GPU.
#
# </div>

# %%
import ray

if not(ray.is_initialized()):
    if is_gpu_available:
        ray.init(num_cpus=n_gpus, num_gpus=n_gpus, log_to_driver=False)            
    else:
        ray.init(num_cpus=1, log_to_driver=False)
# Out:
# 2021-09-30 08:49:14,289	INFO services.py:1263 -- View the Ray dashboard at http://127.0.0.1:8265

# %% [markdown]
# ## A Synthetic Dataset <a class="anchor" id="a-synthetic-dataset"></a>
#
# Now, we will start by defining our artificial dataset based on a Sinus curve. We will first generate data for a **training set** (used for estimation) and a **testing set** (used to evaluate the final performance). Then the training set will be sub-divided in a new **training set** (used to estimate the neural network weights) and **validation set** (used to estimate the neural network hyperparameters and architecture). The data are generated from the following function:
#
# $$ y = f(x) = 2 \cdot \sin(x) + \epsilon$$
#
# The training data will be generated in a range between $[-30, -20]$ with $\epsilon \sim \mathcal{N}(0,0.25)$ and  in a range between $[20, 30]$ with $\epsilon \sim \mathcal{N}(0,1)$. The code for the training data is then corresponding to:

# %%
def load_data_train_test(random_state=42):
    rs = np.random.RandomState(random_state)

    train_size = 400
    f = lambda x: 2*np.sin(x) # a simlpe affine function

    x_1 = rs.uniform(low=-30, high=-20.0, size=train_size//2)
    eps_1 = rs.normal(loc=0.0, scale=0.5, size=train_size//2)
    y_1 = f(x_1) + eps_1

    x_2 = rs.uniform(low=20.0, high=30.0, size=train_size//2)
    eps_2 = rs.normal(loc=0.0, scale=1.0, size=train_size//2)
    y_2 = f(x_2) + eps_2

    x = np.concatenate([x_1, x_2], axis=0)
    y = np.concatenate([y_1, y_2], axis=0)

    x_tst = np.linspace(-40.0, 40.0, 200)
    y_tst = f(x_tst)

    x = x.reshape(-1, 1)
    y = y.reshape(-1, 1)

    x_tst = x_tst.reshape(-1, 1)
    y_tst = y_tst.reshape(-1, 1)

    return (x, y), (x_tst, y_tst)

# %% [markdown]
# Then the code to split the training data in a new **training set** and a **validation set** corresponds to:

# %%
from sklearn.model_selection import train_test_split

def load_data_train_valid(verbose=0, random_state=42):

    (x, y), _ = load_data_train_test(random_state=random_state)

    train_X, valid_X, train_y, valid_y = train_test_split(
        x, y, test_size=0.33, random_state=random_state
    )

    if verbose:
        print(f'train_X shape: {np.shape(train_X)}')
        print(f'train_y shape: {np.shape(train_y)}')
        print(f'valid_X shape: {np.shape(valid_X)}')
        print(f'valid_y shape: {np.shape(valid_y)}')
    return (train_X, train_y), (valid_X, valid_y)


(x, y), (vx, vy) = load_data_train_valid(verbose=1)
_, (tx , ty) = load_data_train_test()
# Out:
# train_X shape: (268, 1)
# train_y shape: (268, 1)
# valid_X shape: (132, 1)
# valid_y shape: (132, 1)

# %% [markdown]
# <div class="alert alert-info">
#
# <b>Note</b>
#
# When it is possible to factorize the two previous function into one, DeepHyper interface requires a function which returns `(train_inputs, train_outputs), (valid_inputs, valid_outputs)`.
#
# </div>
#
# We can give a visualization of this data:

# %%
width = 8
height = width/1.618
plt.figure(figsize=(width, height))

plt.plot(tx.reshape(-1), ty.reshape(-1), "ko--", label="test", alpha=0.5)
plt.plot(x.reshape(-1), y.reshape(-1), "bo", label="train", alpha=0.8)
plt.plot(vx.reshape(-1), vy.reshape(-1), "ro", label="valid", alpha=0.8)

plt.ylabel("$y = f(x)$", fontsize=12)
plt.xlabel("$x$", fontsize=12)

plt.xlim(-40, 40)
plt.legend(loc="upper center", ncol=3, fontsize=12)

plt.show()

# %% [markdown]
# ## Scaling the Data <a class="anchor" id="scaling-the-data"></a>
#
# It is important to apply standard scaling on the input/output data to have faster convergence when training.

# %%
from sklearn.preprocessing import StandardScaler


scaler_x = StandardScaler()
s_x = scaler_x.fit_transform(x)
s_vx = scaler_x.transform(vx)
s_tx = scaler_x.transform(tx)

scaler_y = StandardScaler()
s_y = scaler_y.fit_transform(y)
s_vy = scaler_y.transform(vy)
s_ty = scaler_y.transform(ty)

# %% [markdown]
# ## Baseline Neural Network <a class="anchor" id="baseline-neural-network"></a>
#
# Let us define a baseline neural network based on a regular multi-layer perceptron architecture which learn the mean estimate and minimise the mean squared error.

# %%
input_ = tf.keras.layers.Input(shape=(1,))
out = tf.keras.layers.Dense(200, activation="relu")(input_)
out = tf.keras.layers.Dense(200, activation="relu")(out)
output = tf.keras.layers.Dense(1)(out)
model = tf.keras.Model(input_, output)

optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)
model.compile(optimizer, "mse")

history = model.fit(s_x, s_y, epochs=200, batch_size=4, validation_data=(s_vx, s_vy), verbose=1).history
# Out:
# 2021-09-30 08:49:17.322329: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-09-30 08:49:20.758029: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 38457 MB memory:  -> device: 0, name: A100-SXM4-40GB, pci bus id: 0000:07:00.0, compute capability: 8.0
# 2021-09-30 08:49:20.761204: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 38457 MB memory:  -> device: 1, name: A100-SXM4-40GB, pci bus id: 0000:0f:00.0, compute capability: 8.0
# 2021-09-30 08:49:20.763915: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 38457 MB memory:  -> device: 2, name: A100-SXM4-40GB, pci bus id: 0000:47:00.0, compute capability: 8.0
# 2021-09-30 08:49:20.766659: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 38457 MB memory:  -> device: 3, name: A100-SXM4-40GB, pci bus id: 0000:4e:00.0, compute capability: 8.0
# 2021-09-30 08:49:20.769320: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:4 with 38457 MB memory:  -> device: 4, name: A100-SXM4-40GB, pci bus id: 0000:87:00.0, compute capability: 8.0
# 2021-09-30 08:49:20.772002: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:5 with 38457 MB memory:  -> device: 5, name: A100-SXM4-40GB, pci bus id: 0000:90:00.0, compute capability: 8.0
# 2021-09-30 08:49:20.774693: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:6 with 38457 MB memory:  -> device: 6, name: A100-SXM4-40GB, pci bus id: 0000:b7:00.0, compute capability: 8.0
# 2021-09-30 08:49:20.777594: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:7 with 38457 MB memory:  -> device: 7, name: A100-SXM4-40GB, pci bus id: 0000:bd:00.0, compute capability: 8.0
# 2021-09-30 08:49:21.443605: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/200
# 59/67 [=========================>....] - ETA: 0s - loss: 1.0305
# 2021-09-30 08:49:22.471226: I tensorflow/stream_executor/cuda/cuda_blas.cc:1760] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 67/67 [==============================] - 1s 3ms/step - loss: 1.0199 - val_loss: 1.0872
# Epoch 2/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0141 - val_loss: 1.0732
# Epoch 3/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0100 - val_loss: 1.0724
# Epoch 4/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0029 - val_loss: 1.0709
# Epoch 5/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0037 - val_loss: 1.0816
# Epoch 6/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9993 - val_loss: 1.0692
# Epoch 7/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9996 - val_loss: 1.0739
# Epoch 8/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0004 - val_loss: 1.0678
# Epoch 9/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9970 - val_loss: 1.0771
# Epoch 10/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9986 - val_loss: 1.0630
# Epoch 11/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9994 - val_loss: 1.0730
# Epoch 12/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0013 - val_loss: 1.0652
# Epoch 13/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9979 - val_loss: 1.0655
# Epoch 14/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9953 - val_loss: 1.0699
# Epoch 15/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9917 - val_loss: 1.0703
# Epoch 16/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9960 - val_loss: 1.0598
# Epoch 17/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9973 - val_loss: 1.0602
# Epoch 18/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9908 - val_loss: 1.0580
# Epoch 19/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9885 - val_loss: 1.0603
# Epoch 20/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9928 - val_loss: 1.0604
# Epoch 21/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9930 - val_loss: 1.0595
# Epoch 22/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9908 - val_loss: 1.0550
# Epoch 23/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9889 - val_loss: 1.0557
# Epoch 24/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9820 - val_loss: 1.0592
# Epoch 25/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9815 - val_loss: 1.0500
# Epoch 26/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9785 - val_loss: 1.0549
# Epoch 27/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9905 - val_loss: 1.0477
# Epoch 28/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9762 - val_loss: 1.0516
# Epoch 29/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9900 - val_loss: 1.0609
# Epoch 30/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9829 - val_loss: 1.0425
# Epoch 31/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9753 - val_loss: 1.0379
# Epoch 32/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9750 - val_loss: 1.0436
# Epoch 33/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9782 - val_loss: 1.0341
# Epoch 34/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9733 - val_loss: 1.0359
# Epoch 35/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9627 - val_loss: 1.0431
# Epoch 36/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9644 - val_loss: 1.0355
# Epoch 37/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9666 - val_loss: 1.0345
# Epoch 38/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9604 - val_loss: 1.0633
# Epoch 39/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9643 - val_loss: 1.0400
# Epoch 40/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9565 - val_loss: 1.0606
# Epoch 41/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9638 - val_loss: 1.0178
# Epoch 42/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9501 - val_loss: 1.0235
# Epoch 43/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9349 - val_loss: 1.0140
# Epoch 44/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9448 - val_loss: 1.0252
# Epoch 45/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9383 - val_loss: 1.0182
# Epoch 46/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9286 - val_loss: 1.0087
# Epoch 47/200
# 67/67 [==============================] - 0s 3ms/step - loss: 0.9216 - val_loss: 1.0741
# Epoch 48/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9669 - val_loss: 1.0280
# Epoch 49/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9368 - val_loss: 0.9950
# Epoch 50/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9183 - val_loss: 0.9923
# Epoch 51/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9188 - val_loss: 0.9959
# Epoch 52/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9101 - val_loss: 0.9778
# Epoch 53/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.8941 - val_loss: 1.0093
# Epoch 54/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9110 - val_loss: 0.9786
# Epoch 55/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.8885 - val_loss: 0.9671
# Epoch 56/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.8852 - val_loss: 0.9681
# Epoch 57/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.8752 - val_loss: 0.9616
# Epoch 58/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.8728 - val_loss: 0.9576
# Epoch 59/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.8626 - val_loss: 1.0390
# Epoch 60/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.8984 - val_loss: 0.9502
# Epoch 61/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.8633 - val_loss: 0.9499
# Epoch 62/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.8672 - val_loss: 0.9967
# Epoch 63/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.8542 - val_loss: 0.9231
# Epoch 64/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.8530 - val_loss: 0.9296
# Epoch 65/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.8665 - val_loss: 0.9243
# Epoch 66/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.8714 - val_loss: 0.9904
# Epoch 67/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.8438 - val_loss: 0.9209
# Epoch 68/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.8305 - val_loss: 0.9474
# Epoch 69/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.8314 - val_loss: 0.8935
# Epoch 70/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.8132 - val_loss: 0.9062
# Epoch 71/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.8102 - val_loss: 0.8887
# Epoch 72/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.8281 - val_loss: 0.9194
# Epoch 73/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.7950 - val_loss: 0.9225
# Epoch 74/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.8069 - val_loss: 0.8902
# Epoch 75/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.8029 - val_loss: 0.8719
# Epoch 76/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.8068 - val_loss: 0.8788
# Epoch 77/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.8015 - val_loss: 0.8859
# Epoch 78/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.7808 - val_loss: 0.8785
# Epoch 79/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.7841 - val_loss: 0.8567
# Epoch 80/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.7757 - val_loss: 0.8683
# Epoch 81/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.7772 - val_loss: 0.8661
# Epoch 82/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.7652 - val_loss: 0.8479
# Epoch 83/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.7790 - val_loss: 0.8521
# Epoch 84/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.7607 - val_loss: 0.8403
# Epoch 85/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.7395 - val_loss: 0.8353
# Epoch 86/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.7793 - val_loss: 0.8391
# Epoch 87/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.7393 - val_loss: 0.8424
# Epoch 88/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.7534 - val_loss: 0.8395
# Epoch 89/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.7436 - val_loss: 0.8271
# Epoch 90/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.7209 - val_loss: 0.8250
# Epoch 91/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.7144 - val_loss: 0.7993
# Epoch 92/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.6993 - val_loss: 0.7970
# Epoch 93/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.6957 - val_loss: 0.7906
# Epoch 94/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.7205 - val_loss: 0.8281
# Epoch 95/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.7094 - val_loss: 0.7796
# Epoch 96/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.6873 - val_loss: 0.8243
# Epoch 97/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.7173 - val_loss: 0.8006
# Epoch 98/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.7017 - val_loss: 0.7799
# Epoch 99/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.6829 - val_loss: 0.7512
# Epoch 100/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.6662 - val_loss: 0.7502
# Epoch 101/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.6520 - val_loss: 0.7412
# Epoch 102/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.6540 - val_loss: 0.7502
# Epoch 103/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.6489 - val_loss: 0.7394
# Epoch 104/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.6496 - val_loss: 0.7448
# Epoch 105/200
# 67/67 [==============================] - 0s 3ms/step - loss: 0.6467 - val_loss: 0.7646
# Epoch 106/200
# 67/67 [==============================] - 0s 3ms/step - loss: 0.6329 - val_loss: 0.7163
# Epoch 107/200
# 67/67 [==============================] - 0s 3ms/step - loss: 0.6304 - val_loss: 0.7752
# Epoch 108/200
# 67/67 [==============================] - 0s 3ms/step - loss: 0.6229 - val_loss: 0.7124
# Epoch 109/200
# 67/67 [==============================] - 0s 3ms/step - loss: 0.6040 - val_loss: 0.6994
# Epoch 110/200
# 67/67 [==============================] - 0s 3ms/step - loss: 0.6033 - val_loss: 0.6935
# Epoch 111/200
# 67/67 [==============================] - 0s 3ms/step - loss: 0.5877 - val_loss: 0.6710
# Epoch 112/200
# 67/67 [==============================] - 0s 3ms/step - loss: 0.6222 - val_loss: 0.6951
# Epoch 113/200
# 67/67 [==============================] - 0s 3ms/step - loss: 0.5760 - val_loss: 0.6702
# Epoch 114/200
# 67/67 [==============================] - 0s 3ms/step - loss: 0.5594 - val_loss: 0.6753
# Epoch 115/200
# 67/67 [==============================] - 0s 3ms/step - loss: 0.5417 - val_loss: 0.6458
# Epoch 116/200
# 67/67 [==============================] - 0s 3ms/step - loss: 0.5542 - val_loss: 0.6381
# Epoch 117/200
# 67/67 [==============================] - 0s 3ms/step - loss: 0.5384 - val_loss: 0.6848
# Epoch 118/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.5503 - val_loss: 0.6326
# Epoch 119/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.5159 - val_loss: 0.6165
# Epoch 120/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.5040 - val_loss: 0.6371
# Epoch 121/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.5565 - val_loss: 0.6060
# Epoch 122/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.5015 - val_loss: 0.6111
# Epoch 123/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.5229 - val_loss: 0.5993
# Epoch 124/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.5213 - val_loss: 0.6125
# Epoch 125/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.5165 - val_loss: 0.5892
# Epoch 126/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.4939 - val_loss: 0.6318
# Epoch 127/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.4754 - val_loss: 0.6769
# Epoch 128/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.4713 - val_loss: 0.6930
# Epoch 129/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.4649 - val_loss: 0.5863
# Epoch 130/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.4721 - val_loss: 0.5885
# Epoch 131/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.5016 - val_loss: 0.5881
# Epoch 132/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.4818 - val_loss: 0.5723
# Epoch 133/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.4885 - val_loss: 0.6162
# Epoch 134/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.4944 - val_loss: 0.5986
# Epoch 135/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.4699 - val_loss: 0.5735
# Epoch 136/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.4974 - val_loss: 0.5856
# Epoch 137/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.4833 - val_loss: 0.6273
# Epoch 138/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.4851 - val_loss: 0.5526
# Epoch 139/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.4397 - val_loss: 0.5956
# Epoch 140/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.4371 - val_loss: 0.5722
# Epoch 141/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.4293 - val_loss: 0.6144
# Epoch 142/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.4369 - val_loss: 0.6128
# Epoch 143/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.4553 - val_loss: 0.5743
# Epoch 144/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.4851 - val_loss: 0.5525
# Epoch 145/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.4362 - val_loss: 0.6091
# Epoch 146/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.4450 - val_loss: 0.5450
# Epoch 147/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.4323 - val_loss: 0.5585
# Epoch 148/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.4410 - val_loss: 0.5810
# Epoch 149/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.4581 - val_loss: 0.5568
# Epoch 150/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.4280 - val_loss: 0.6453
# Epoch 151/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.4506 - val_loss: 0.6274
# Epoch 152/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.4267 - val_loss: 0.5990
# Epoch 153/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.4139 - val_loss: 0.5269
# Epoch 154/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.4326 - val_loss: 0.5769
# Epoch 155/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.4642 - val_loss: 0.5475
# Epoch 156/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.4368 - val_loss: 0.5212
# Epoch 157/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.4095 - val_loss: 0.5337
# Epoch 158/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.4134 - val_loss: 0.5324
# Epoch 159/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.4228 - val_loss: 0.6195
# Epoch 160/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.4100 - val_loss: 0.5517
# Epoch 161/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.4045 - val_loss: 0.5094
# Epoch 162/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.4151 - val_loss: 0.5559
# Epoch 163/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.4134 - val_loss: 0.6287
# Epoch 164/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.3763 - val_loss: 0.4823
# Epoch 165/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.3727 - val_loss: 0.4880
# Epoch 166/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.3766 - val_loss: 0.5374
# Epoch 167/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.3723 - val_loss: 0.5754
# Epoch 168/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.3674 - val_loss: 0.4646
# Epoch 169/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.3798 - val_loss: 0.5292
# Epoch 170/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.3721 - val_loss: 0.5048
# Epoch 171/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.3537 - val_loss: 0.5429
# Epoch 172/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.3772 - val_loss: 0.5470
# Epoch 173/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.3552 - val_loss: 0.4771
# Epoch 174/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.3252 - val_loss: 0.4749
# Epoch 175/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.3281 - val_loss: 0.4782
# Epoch 176/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.3373 - val_loss: 0.4637
# Epoch 177/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.3304 - val_loss: 0.4503
# Epoch 178/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.3003 - val_loss: 0.4139
# Epoch 179/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.3293 - val_loss: 0.4030
# Epoch 180/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.2938 - val_loss: 0.4247
# Epoch 181/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.2718 - val_loss: 0.4389
# Epoch 182/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.3030 - val_loss: 0.3900
# Epoch 183/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.2761 - val_loss: 0.3961
# Epoch 184/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.2757 - val_loss: 0.3926
# Epoch 185/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.2714 - val_loss: 0.3754
# Epoch 186/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.2566 - val_loss: 0.3922
# Epoch 187/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.2615 - val_loss: 0.3823
# Epoch 188/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.2772 - val_loss: 0.3680
# Epoch 189/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.2427 - val_loss: 0.3739
# Epoch 190/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.2582 - val_loss: 0.3853
# Epoch 191/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.2335 - val_loss: 0.3439
# Epoch 192/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.2527 - val_loss: 0.3426
# Epoch 193/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.2450 - val_loss: 0.3515
# Epoch 194/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.2551 - val_loss: 0.3251
# Epoch 195/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.2622 - val_loss: 0.3697
# Epoch 196/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.2380 - val_loss: 0.3184
# Epoch 197/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.2640 - val_loss: 0.3638
# Epoch 198/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.2283 - val_loss: 0.3881
# Epoch 199/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.2180 - val_loss: 0.3325
# Epoch 200/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.2417 - val_loss: 0.4459

# %% [markdown]
# We can do a vizualisation of our learning curves to make sure the training and validation loss decrease correctly.

# %%
width = 8
height = width/1.618
plt.figure(figsize=(width, height))

plt.plot(history["loss"], label="training")
plt.plot(history["val_loss"], label="validation")

plt.xlabel("Epochs")
plt.ylabel("MSE")

plt.legend()

plt.show()

# %% [markdown]
# Also, let us look at the prediction on the test set after reversing the scaling of predicted variables.

# %%
pred_s_ty = model(s_tx)
pred_ty = scaler_y.inverse_transform(pred_s_ty)

width = 8
height = width/1.618
plt.figure(figsize=(width, height))

plt.plot(tx, ty, label="truth")
plt.plot(tx, pred_ty, label="pred")

y_lim = 10
plt.fill_between([-30, -20], [-y_lim, -y_lim], [y_lim, y_lim], color="grey", alpha=0.5)
plt.fill_between([20, 30], [-y_lim, -y_lim], [y_lim, y_lim], color="grey", alpha=0.5)

plt.legend()
plt.ylim(-y_lim, y_lim)

plt.show()

# %% [markdown]
# ## Define the Neural Architecture Search Space <a class="anchor" id="define-the-neural-architecture-search-space"></a>
#
# The neural architecture search space is composed of discrete decision variables. For each decision variable we choose among a list of possible operation to perform (e.g., fully connected, ReLU). To define this search space, it is necessary to use two classes:
#
# * `KSearchSpace` (for Keras Search Space): represents a directed acyclic graph (DAG) in which each node represents a chosen operation. It represents the possible neural networks that can be created.
# * `SpaceFactory`: is a utilitiy class used to pack the logic of a search space definition and share it with others.
#
# Then, inside a `KSearchSpace` we will have two types of nodes:
# * `VariableNode`: corresponds to discrete decision variables and are used to define a list of possible operation.
# * `ConstantNode`: corresponds to fixed operation in the search space (e.g., input/outputs)
#
# Finally, it is possible to reuse any `tf.keras.layers` to define a `KSearchSpace`. However, it is important to wrap each layer in an `operation` to perform a lazy memory allocation of tensors.

# %%
import collections

from deephyper.nas.space import KSearchSpace, SpaceFactory

# Decision variables are represented by nodes in a graph
from deephyper.nas.space.node import ConstantNode, VariableNode

# For Skip/Residual connections
from deephyper.nas.space.op.basic import Zero
from deephyper.nas.space.op.connect import Connect
from deephyper.nas.space.op.merge import AddByProjecting

from deephyper.nas.space.op.op1d import Identity

# The "operation" creates a wrapper around Keras layers
# to avoid allocating memory each time a new layer is defined
# in the search space
from deephyper.nas.space.op import operation

Dense = operation(tf.keras.layers.Dense)

# Possible activation functions
ACTIVATIONS = [
    tf.keras.activations.elu,
    tf.keras.activations.gelu,
    tf.keras.activations.hard_sigmoid,
    tf.keras.activations.linear,
    tf.keras.activations.relu,
    tf.keras.activations.selu,
    tf.keras.activations.sigmoid,
    tf.keras.activations.softplus,
    tf.keras.activations.softsign,
    tf.keras.activations.swish,
    tf.keras.activations.tanh,
]

# %% [markdown]
# We implement the `build` method of the `RegressionFactory` which is a subclass of `SpaceFactory`. The `build` method interface is:
#
# ```python
# def build(self, input_shape, output_shape, **kwargs) -> KSearchSpace:
#     ...
# ```
#
# where:
# * `input_shape` corresponds to a tuple or a list of tuple indicating the shapes of inputs tensors.
# * `output_shape` corresponds to the same but of output_tensors.
# * `**kwargs` denotes that any other key word argument can be defined by the user.
#
# This method has to return an object of type `KSearchSpace`.

# %%
class RegressionFactory(SpaceFactory):
    
    def build(self, input_shape, output_shape, num_layers=3, **kwargs):

        self.ss = KSearchSpace(input_shape, output_shape)
        
        # After creating a KSearchSpace nodes corresponds to the inputs are directly accessible
        out_sub_graph = self.build_sub_graph(self.ss.input_nodes[0], num_layers)

        output = ConstantNode(op=Dense(output_shape[0]))  
        self.ss.connect(out_sub_graph, output)

        return self.ss

    def build_sub_graph(self, input_node, num_layers=3):
        

        # Look over skip connections within a range of the 3 previous nodes
        anchor_points = collections.deque([input_node], maxlen=3)
        
        prev_node = input_node
        
        for _ in range(num_layers):
            
            # Create a variable node to list possible "Dense" layers
            dense = VariableNode()
            
            # Add the possible operations to the dense node
            self.add_dense_to_(dense)
            
            # Connect the previous node to the dense node
            self.ss.connect(prev_node, dense)

            # Create a constant node to merge all input connections
            merge = ConstantNode()
            merge.set_op(
                AddByProjecting(self.ss, [dense], activation="relu")
            )

            for node in anchor_points:
                
                # Create a variable node for each possible connection
                skipco = VariableNode()
                
                skipco.add_op(Zero()) # corresponds to no connection
                skipco.add_op(Connect(self.ss, node)) # corresponds to (node => skipco)
                
                # Connect the (skipco => merge)
                self.ss.connect(skipco, merge)

 
            # ! for next iter
            prev_node = merge
            anchor_points.append(prev_node)

        return prev_node

    def add_dense_to_(self, node):
        
        # We add the "Identity" operation to allow the choice "doing nothing"
        node.add_op(Identity())
        
        step = 16
        for units in range(step, step * 16 + 1, step):
            for activation in ACTIVATIONS:
                node.add_op(Dense(units=units, activation=activation))


def create_search_space(input_shape=(1,), output_shape=(1,), **kwargs):    
    return RegressionFactory()(input_shape, output_shape, **kwargs)

# %% [markdown]
# Let us visualize a few randomly sampled neural architecture from this search space.

# %%
import matplotlib.image as mpimg


shapes = dict(input_shape=(1,), output_shape=(1,))
factory = RegressionFactory()
    

images = []
plt.figure(figsize=(15,15))
for i in range(4):

    plt.subplot(2,2,i+1)
    factory.plot_model(**shapes, show_shapes=False, show_layer_names=False)
    image = mpimg.imread("random_model.png")
    plt.imshow(image)
    plt.axis('off')

plt.show()

# %% [markdown]
# ## Define the Neural Architecture Optimization Problem <a class="anchor" id="define-the-neural-architecture-search-optimization-problem"></a>
#
# In order to define a neural architecture search problem we have to use the `NaProblem` class. This class gives access to different method for the user to customize the training settings of neural networks.

# %%
from deephyper.problem import NaProblem


def stdscaler():
    return StandardScaler()


problem = NaProblem()

# Bind a function which returns (train_input, train_output), (valid_input, valid_output)
problem.load_data(load_data_train_valid)

# Bind a function which return a scikit-learn preprocessor (with fit, fit_transform, inv_transform...etc)
problem.preprocessing(stdscaler)

# Bind a function which returns a search space and give some arguments for the `build` method
problem.search_space(create_search_space, num_layers=3)

# Define a set of fixed hyperparameters for all trained neural networks
problem.hyperparameters(
    batch_size=4,
    learning_rate=1e-3,
    optimizer="adam",
    num_epochs=200,
    callbacks=dict(
        EarlyStopping=dict(monitor="val_loss", mode="min", verbose=0, patience=30)
    ),
)

# Define the loss to minimize
problem.loss("mse")

# Define complementary metrics
problem.metrics([])

# Define the maximized objective. Here we take the negative of the validation loss.
problem.objective("-val_loss")

problem
# Out:
# Problem is:
#  * SEED = None *
#     - search space   : __main__.create_search_space
#     - data loading   : __main__.load_data_train_valid
#     - preprocessing  : __main__.stdscaler
#     - hyperparameters:
#         * verbose: 0
#         * batch_size: 4
#         * learning_rate: 0.001
#         * optimizer: adam
#         * num_epochs: 200
#         * callbacks: {'EarlyStopping': {'monitor': 'val_loss', 'mode': 'min', 'verbose': 0, 'patience': 30}}
#     - loss           : mse
#     - metrics        :
#     - objective      : -val_loss
#     - post-training  : None

# %% [markdown]
# <div class="alert alert-info">
#
# <b>Tip</b>
#
# Adding an `EarlyStopping(...)` callback is a good idea to stop the training of your model as soon as it stops to improve.
#
# ```python
# ...
# EarlyStopping=dict(monitor="val_loss", mode="min", verbose=0, patience=30)
# ...
# ```
#
# </div>

# %% [markdown]
# ## Define the Evaluator Object
#
# The `Evaluator` object is responsible of defining the backend used to distribute the function evaluation in DeepHyper.

# %%
from deephyper.evaluator.evaluate import Evaluator
from deephyper.evaluator.callback import LoggerCallback


def get_evaluator(run_function):
    
    # Default arguments for Ray: 1 worker and 1 worker per evaluation
    method_kwargs = {
        "num_cpus": 1, 
        "num_cpus_per_task": 1,
        "callbacks": [LoggerCallback()] # To interactively follow the finished evaluations,
    }

    # If GPU devices are detected then it will create 'n_gpus' workers
    # and use 1 worker for each evaluation
    if is_gpu_available:
        method_kwargs["num_cpus"] = n_gpus
        method_kwargs["num_gpus"] = n_gpus
        method_kwargs["num_cpus_per_task"] = 1
        method_kwargs["num_gpus_per_task"] = 1

    evaluator = Evaluator.create(
        run_function, 
        method="ray", 
        method_kwargs=method_kwargs
    )
    print(f"Created new evaluator with {evaluator.num_workers} worker{'s' if evaluator.num_workers > 1 else ''} and config: {method_kwargs}", )
    
    return evaluator

# %% [markdown]
# For neural architecture search a standard training pipeline is provided by the `deephyper.nas.run.alpha.run` function.

# %%
from deephyper.nas.run.alpha import run as run_nas

# %% [markdown]
# ## Define and Run the Neural Architecture Search
#
# All search algorithms follow a similar interface. A `problem` and `evaluator` object has to be provided to the search then the search can be executed through the `search(max_evals, timeout)` method.

# %%
results = {} # used to store the results of different search algorithms
max_evals = 10 # maximum number of iteratins for all searches

# %%
from deephyper.search.nas.random import Random

random_search = Random(problem, get_evaluator(run_nas))

results["random"] = random_search.search(max_evals=max_evals)
# Out:
# Created new evaluator with 7 workers and config: {'num_cpus': 7, 'num_cpus_per_task': 1, 'callbacks': [<deephyper.evaluator.callback.LoggerCallback object at 0x7f4bb80e48b0>], 'num_gpus': 7, 'num_gpus_per_task': 1}
# [00001] -- best objective: -1.0764005184173584 -- received objective: -1.0764005184173584
# [00002] -- best objective: -0.9935415983200073 -- received objective: -0.9935415983200073
# [00003] -- best objective: -0.9935415983200073 -- received objective: -1.040484070777893
# [00004] -- best objective: -0.3920416533946991 -- received objective: -0.3920416533946991
# [00005] -- best objective: -0.3900957703590393 -- received objective: -0.3900957703590393
# [00006] -- best objective: -0.32803547382354736 -- received objective: -0.32803547382354736
# [00007] -- best objective: -0.32803547382354736 -- received objective: -0.36243903636932373
# [00008] -- best objective: -0.32803547382354736 -- received objective: -1.035335898399353
# [00009] -- best objective: -0.32803547382354736 -- received objective: -0.3573792278766632
# [00010] -- best objective: -0.32803547382354736 -- received objective: -1.0231266021728516

# %% [markdown]
# By default, the `RegularizedEvolution` has a population size of 100 therefore, it will start optimizing only after 100 evaluations.

# %%
from deephyper.search.nas.regevo import RegularizedEvolution

regevo_search = RegularizedEvolution(problem, get_evaluator(run_nas))

results["regevo"] = regevo_search.search(max_evals=max_evals)
# Out:
# Created new evaluator with 7 workers and config: {'num_cpus': 7, 'num_cpus_per_task': 1, 'callbacks': [<deephyper.evaluator.callback.LoggerCallback object at 0x7f4bb80e4250>], 'num_gpus': 7, 'num_gpus_per_task': 1}
# [00001] -- best objective: -1.0750333070755005 -- received objective: -1.0750333070755005
# [00002] -- best objective: -1.0750333070755005 -- received objective: -1.0770924091339111
# [00003] -- best objective: -0.45093491673469543 -- received objective: -0.45093491673469543
# [00004] -- best objective: -0.32505008578300476 -- received objective: -0.32505008578300476
# [00005] -- best objective: -0.32505008578300476 -- received objective: -1.0261223316192627
# [00006] -- best objective: -0.32505008578300476 -- received objective: -0.9786860346794128
# [00007] -- best objective: -0.32505008578300476 -- received objective: -1.0816012620925903
# [00008] -- best objective: -0.32505008578300476 -- received objective: -0.7979997992515564
# [00009] -- best objective: -0.32505008578300476 -- received objective: -0.4001121520996094
# [00010] -- best objective: -0.32505008578300476 -- received objective: -1.0765492916107178

# %% [markdown]
# We can now compare the search trajectories for different algorithms.

# %%
def max_score(l):
    r = [l[0]]
    for el in l[1:]:
        r.append(max(r[-1], el))
    return r

width = 8
height = width/1.618
plt.figure(figsize=(width, height))

for k, result in results.items():
    plt.plot(max_score(results[k].objective), label=k)
    
plt.legend()
    
plt.show()

# %% [markdown]
# If we look at the dataframe of results for each search we will find it slightly different than the one of hyperparameter search. A new column `arch_seq` corresponds to an embedding for each evaluated architecture. Each integer of an `arch_seq` list corresponds to the choice of a `VariableNode` in our `KSearchSpace`.

# %%
results["random"]
# Out:
#                             arch_seq  id  objective  elapsed_sec   duration
# 0     [71, 0, 37, 0, 1, 81, 0, 0, 1]   1  -1.076401    11.578130  11.564654
# 1    [64, 0, 155, 0, 0, 20, 1, 0, 0]   6  -0.993542    23.918868  23.905342
# 2     [11, 0, 77, 1, 1, 53, 0, 0, 0]   3  -1.040484    27.371324  27.357816
# 3   [132, 1, 126, 0, 1, 64, 0, 0, 0]   7  -0.392042    28.253725  28.240193
# 4  [109, 1, 164, 1, 1, 170, 0, 1, 1]   4  -0.390096    34.488076  34.474564
# 5     [81, 1, 45, 1, 1, 97, 0, 1, 0]   2  -0.328035    35.994130  35.980637
# 6    [5, 1, 124, 0, 1, 173, 0, 1, 0]   5  -0.362439    40.737132  40.723614
# 7    [138, 0, 28, 1, 0, 49, 1, 0, 0]   8  -1.035336    42.300362  30.719799
# 8    [103, 1, 37, 0, 0, 68, 0, 1, 1]   9  -0.357379    50.953083  27.032915
# 9    [66, 0, 98, 0, 1, 142, 1, 1, 0]  11  -1.023127    51.228996  22.973982

# %% [markdown]
# Let us visualize the best architecture found:

# %%
i_max = results["random"].objective.argmax()
best_score = results["random"].iloc[i_max].objective
best_arch_seq = json.loads(results["random"].iloc[i_max].arch_seq)

factory.plot_model(arch_seq=best_arch_seq, **shapes, show_shapes=True, show_layer_names=False)

# %% [markdown]
# ## Adding Uncertainty Quantification to the Baseline Neural Network
#
# To add uncertainty estimates we use the [Tensorflow Probability](https://www.tensorflow.org/probability) library which is fully compatible with the neural architecture search API because it is accessible through Keras layers.

# %%
import tensorflow_probability as tfp
tfd = tfp.distributions

# %% [markdown]
# Then, instead of minimising the mean squared error we will minimize the negative log-likelihood baed on the learned probability distribution $p(y|\mathbf{x};\theta)$ where $\theta$ represents a neural network (architecture, training hyperparameters, weights).

# %%
def nll(y, rv_y):
    """Negative log likelihood for Tensorflow probability.
    
    Args:
        y: true data.
        rv_y: learned (predicted) probability distribution.
    """
    return -rv_y.log_prob(y)

# %%
input_ = tf.keras.layers.Input(shape=(1,))
out = tf.keras.layers.Dense(200, activation="relu")(input_)
out = tf.keras.layers.Dense(200, activation="relu")(out)

# For each predicted variable (1) we need the mean and variance estimate
out = tf.keras.layers.Dense(1*2)(out) 

# We feed these estimates to output a Normal distribution for each predicted variable
output = tfp.layers.DistributionLambda(
            lambda t: tfd.Normal(
                loc=t[..., :1],
                scale=1e-3 + tf.math.softplus(0.05 * t[..., 1:]), # positive constraint on the standard dev.
            )
        )(out)

model_uq = tf.keras.Model(input_, output)

optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)
model_uq.compile(optimizer, loss=nll)

history = model_uq.fit(s_x, s_y, epochs=200, batch_size=4, validation_data=(s_vx, s_vy), verbose=1)
# Out:
# 2021-09-30 08:52:40.386365: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# Epoch 1/200
# 67/67 [==============================] - 1s 4ms/step - loss: 1.6089 - val_loss: 1.6603
# Epoch 2/200
# 67/67 [==============================] - 0s 3ms/step - loss: 1.5674 - val_loss: 1.6037
# Epoch 3/200
# 67/67 [==============================] - 0s 3ms/step - loss: 1.5210 - val_loss: 1.5638
# Epoch 4/200
# 67/67 [==============================] - 0s 3ms/step - loss: 1.4922 - val_loss: 1.5055
# Epoch 5/200
# 67/67 [==============================] - 0s 3ms/step - loss: 1.4496 - val_loss: 1.4679
# Epoch 6/200
# 67/67 [==============================] - 0s 3ms/step - loss: 1.4569 - val_loss: 1.4577
# Epoch 7/200
# 67/67 [==============================] - 0s 3ms/step - loss: 1.4304 - val_loss: 1.4516
# Epoch 8/200
# 67/67 [==============================] - 0s 3ms/step - loss: 1.4318 - val_loss: 1.4537
# Epoch 9/200
# 67/67 [==============================] - 0s 3ms/step - loss: 1.4344 - val_loss: 1.4542
# Epoch 10/200
# 67/67 [==============================] - 0s 3ms/step - loss: 1.4260 - val_loss: 1.4849
# Epoch 11/200
# 67/67 [==============================] - 0s 3ms/step - loss: 1.4276 - val_loss: 1.4624
# Epoch 12/200
# 67/67 [==============================] - 0s 3ms/step - loss: 1.4253 - val_loss: 1.4553
# Epoch 13/200
# 67/67 [==============================] - 0s 3ms/step - loss: 1.4253 - val_loss: 1.4486
# Epoch 14/200
# 67/67 [==============================] - 0s 3ms/step - loss: 1.4250 - val_loss: 1.4514
# Epoch 15/200
# 67/67 [==============================] - 0s 3ms/step - loss: 1.4289 - val_loss: 1.4724
# Epoch 16/200
# 67/67 [==============================] - 0s 3ms/step - loss: 1.4177 - val_loss: 1.4854
# Epoch 17/200
# 67/67 [==============================] - 0s 3ms/step - loss: 1.4292 - val_loss: 1.4565
# Epoch 18/200
# 67/67 [==============================] - 0s 3ms/step - loss: 1.4304 - val_loss: 1.4500
# Epoch 19/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.4183 - val_loss: 1.4872
# Epoch 20/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.4274 - val_loss: 1.4569
# Epoch 21/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.4163 - val_loss: 1.4500
# Epoch 22/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.4267 - val_loss: 1.4525
# Epoch 23/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.4182 - val_loss: 1.4454
# Epoch 24/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.4164 - val_loss: 1.4542
# Epoch 25/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.4150 - val_loss: 1.4617
# Epoch 26/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.4197 - val_loss: 1.4460
# Epoch 27/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.4206 - val_loss: 1.4506
# Epoch 28/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.4206 - val_loss: 1.4465
# Epoch 29/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.4160 - val_loss: 1.4462
# Epoch 30/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.4174 - val_loss: 1.4500
# Epoch 31/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.4174 - val_loss: 1.4516
# Epoch 32/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.4133 - val_loss: 1.4656
# Epoch 33/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.4146 - val_loss: 1.4494
# Epoch 34/200
# 67/67 [==============================] - 0s 3ms/step - loss: 1.4124 - val_loss: 1.4413
# Epoch 35/200
# 67/67 [==============================] - 0s 3ms/step - loss: 1.4138 - val_loss: 1.4449
# Epoch 36/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.4138 - val_loss: 1.4632
# Epoch 37/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.4108 - val_loss: 1.4596
# Epoch 38/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.4148 - val_loss: 1.4459
# Epoch 39/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.4070 - val_loss: 1.4466
# Epoch 40/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.4066 - val_loss: 1.4437
# Epoch 41/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.4052 - val_loss: 1.4479
# Epoch 42/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3982 - val_loss: 1.4590
# Epoch 43/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.4229 - val_loss: 1.4443
# Epoch 44/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.4002 - val_loss: 1.4473
# Epoch 45/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.4131 - val_loss: 1.4417
# Epoch 46/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.4024 - val_loss: 1.4530
# Epoch 47/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3986 - val_loss: 1.4438
# Epoch 48/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.4019 - val_loss: 1.4386
# Epoch 49/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3972 - val_loss: 1.4419
# Epoch 50/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.4048 - val_loss: 1.4482
# Epoch 51/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.4022 - val_loss: 1.4364
# Epoch 52/200
# 67/67 [==============================] - 0s 3ms/step - loss: 1.4323 - val_loss: 1.4385
# Epoch 53/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3993 - val_loss: 1.4522
# Epoch 54/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.4123 - val_loss: 1.4420
# Epoch 55/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.4024 - val_loss: 1.4397
# Epoch 56/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.4052 - val_loss: 1.4297
# Epoch 57/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.4008 - val_loss: 1.4337
# Epoch 58/200
# 67/67 [==============================] - 0s 3ms/step - loss: 1.4087 - val_loss: 1.4342
# Epoch 59/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3959 - val_loss: 1.4416
# Epoch 60/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3936 - val_loss: 1.4815
# Epoch 61/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3899 - val_loss: 1.5056
# Epoch 62/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.4177 - val_loss: 1.4326
# Epoch 63/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3988 - val_loss: 1.4363
# Epoch 64/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3984 - val_loss: 1.4317
# Epoch 65/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3978 - val_loss: 1.4319
# Epoch 66/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3951 - val_loss: 1.4336
# Epoch 67/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.4001 - val_loss: 1.4447
# Epoch 68/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3985 - val_loss: 1.4582
# Epoch 69/200
# 67/67 [==============================] - 0s 3ms/step - loss: 1.4004 - val_loss: 1.4318
# Epoch 70/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.4041 - val_loss: 1.4324
# Epoch 71/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3940 - val_loss: 1.4494
# Epoch 72/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3941 - val_loss: 1.4397
# Epoch 73/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3966 - val_loss: 1.4422
# Epoch 74/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.4059 - val_loss: 1.4292
# Epoch 75/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3989 - val_loss: 1.4528
# Epoch 76/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.4096 - val_loss: 1.4403
# Epoch 77/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.4042 - val_loss: 1.4358
# Epoch 78/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.4000 - val_loss: 1.4284
# Epoch 79/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3964 - val_loss: 1.4368
# Epoch 80/200
# 67/67 [==============================] - 0s 3ms/step - loss: 1.3941 - val_loss: 1.4417
# Epoch 81/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3922 - val_loss: 1.4300
# Epoch 82/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3918 - val_loss: 1.4262
# Epoch 83/200
# 67/67 [==============================] - 0s 3ms/step - loss: 1.3929 - val_loss: 1.4509
# Epoch 84/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3885 - val_loss: 1.4316
# Epoch 85/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3840 - val_loss: 1.4396
# Epoch 86/200
# 67/67 [==============================] - 0s 3ms/step - loss: 1.3868 - val_loss: 1.4328
# Epoch 87/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3855 - val_loss: 1.4397
# Epoch 88/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3873 - val_loss: 1.4476
# Epoch 89/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3844 - val_loss: 1.4281
# Epoch 90/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3874 - val_loss: 1.4277
# Epoch 91/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3814 - val_loss: 1.4196
# Epoch 92/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3824 - val_loss: 1.4544
# Epoch 93/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3866 - val_loss: 1.4422
# Epoch 94/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3759 - val_loss: 1.4318
# Epoch 95/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3785 - val_loss: 1.4629
# Epoch 96/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3806 - val_loss: 1.4194
# Epoch 97/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3730 - val_loss: 1.4148
# Epoch 98/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3746 - val_loss: 1.4274
# Epoch 99/200
# 67/67 [==============================] - 0s 3ms/step - loss: 1.3747 - val_loss: 1.4308
# Epoch 100/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3750 - val_loss: 1.4239
# Epoch 101/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3749 - val_loss: 1.4331
# Epoch 102/200
# 67/67 [==============================] - 0s 3ms/step - loss: 1.3673 - val_loss: 1.4303
# Epoch 103/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3636 - val_loss: 1.4165
# Epoch 104/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3609 - val_loss: 1.4188
# Epoch 105/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3553 - val_loss: 1.4386
# Epoch 106/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3620 - val_loss: 1.4462
# Epoch 107/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3661 - val_loss: 1.4103
# Epoch 108/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3587 - val_loss: 1.4107
# Epoch 109/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3619 - val_loss: 1.4219
# Epoch 110/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3505 - val_loss: 1.4143
# Epoch 111/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3512 - val_loss: 1.4080
# Epoch 112/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3526 - val_loss: 1.4136
# Epoch 113/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3457 - val_loss: 1.4348
# Epoch 114/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3513 - val_loss: 1.4053
# Epoch 115/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3574 - val_loss: 1.4143
# Epoch 116/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3442 - val_loss: 1.4073
# Epoch 117/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3480 - val_loss: 1.4230
# Epoch 118/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3419 - val_loss: 1.4287
# Epoch 119/200
# 67/67 [==============================] - 0s 3ms/step - loss: 1.3404 - val_loss: 1.4079
# Epoch 120/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3427 - val_loss: 1.3936
# Epoch 121/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3328 - val_loss: 1.3928
# Epoch 122/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3353 - val_loss: 1.3901
# Epoch 123/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3427 - val_loss: 1.4376
# Epoch 124/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3296 - val_loss: 1.3927
# Epoch 125/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3412 - val_loss: 1.3924
# Epoch 126/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3349 - val_loss: 1.4386
# Epoch 127/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3403 - val_loss: 1.3858
# Epoch 128/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3246 - val_loss: 1.3851
# Epoch 129/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3254 - val_loss: 1.3812
# Epoch 130/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3161 - val_loss: 1.3888
# Epoch 131/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3254 - val_loss: 1.3798
# Epoch 132/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3092 - val_loss: 1.3718
# Epoch 133/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3067 - val_loss: 1.3764
# Epoch 134/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3052 - val_loss: 1.3740
# Epoch 135/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3103 - val_loss: 1.3659
# Epoch 136/200
# 67/67 [==============================] - 0s 3ms/step - loss: 1.3001 - val_loss: 1.4173
# Epoch 137/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3182 - val_loss: 1.4128
# Epoch 138/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2911 - val_loss: 1.3650
# Epoch 139/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2897 - val_loss: 1.3743
# Epoch 140/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2959 - val_loss: 1.3539
# Epoch 141/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2898 - val_loss: 1.3485
# Epoch 142/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.3034 - val_loss: 1.3943
# Epoch 143/200
# 67/67 [==============================] - 0s 3ms/step - loss: 1.2860 - val_loss: 1.3461
# Epoch 144/200
# 67/67 [==============================] - 0s 3ms/step - loss: 1.2737 - val_loss: 1.3459
# Epoch 145/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2735 - val_loss: 1.3491
# Epoch 146/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2746 - val_loss: 1.3601
# Epoch 147/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2626 - val_loss: 1.3476
# Epoch 148/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2594 - val_loss: 1.3622
# Epoch 149/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2723 - val_loss: 1.3314
# Epoch 150/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2785 - val_loss: 1.3618
# Epoch 151/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2584 - val_loss: 1.3261
# Epoch 152/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2555 - val_loss: 1.3355
# Epoch 153/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2424 - val_loss: 1.3706
# Epoch 154/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2424 - val_loss: 1.3158
# Epoch 155/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2274 - val_loss: 1.3158
# Epoch 156/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2369 - val_loss: 1.3050
# Epoch 157/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2425 - val_loss: 1.2992
# Epoch 158/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2143 - val_loss: 1.3370
# Epoch 159/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2362 - val_loss: 1.3039
# Epoch 160/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2222 - val_loss: 1.2818
# Epoch 161/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2189 - val_loss: 1.3079
# Epoch 162/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2231 - val_loss: 1.3299
# Epoch 163/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2157 - val_loss: 1.2722
# Epoch 164/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2176 - val_loss: 1.2673
# Epoch 165/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.1859 - val_loss: 1.2655
# Epoch 166/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.1841 - val_loss: 1.2519
# Epoch 167/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.1959 - val_loss: 1.2524
# Epoch 168/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2402 - val_loss: 1.2543
# Epoch 169/200
# 67/67 [==============================] - 0s 3ms/step - loss: 1.1800 - val_loss: 1.2444
# Epoch 170/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.1618 - val_loss: 1.2706
# Epoch 171/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.1619 - val_loss: 1.2889
# Epoch 172/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.1519 - val_loss: 1.2473
# Epoch 173/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.1402 - val_loss: 1.2240
# Epoch 174/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.1727 - val_loss: 1.2467
# Epoch 175/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.1428 - val_loss: 1.3679
# Epoch 176/200
# 67/67 [==============================] - 0s 3ms/step - loss: 1.1537 - val_loss: 1.2526
# Epoch 177/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.1323 - val_loss: 1.2011
# Epoch 178/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.1319 - val_loss: 1.2305
# Epoch 179/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.1333 - val_loss: 1.1648
# Epoch 180/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.1261 - val_loss: 1.2400
# Epoch 181/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0992 - val_loss: 1.1834
# Epoch 182/200
# 67/67 [==============================] - 0s 3ms/step - loss: 1.0634 - val_loss: 1.1589
# Epoch 183/200
# 67/67 [==============================] - 0s 3ms/step - loss: 1.1363 - val_loss: 1.1838
# Epoch 184/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.1034 - val_loss: 1.1282
# Epoch 185/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0556 - val_loss: 1.1172
# Epoch 186/200
# 67/67 [==============================] - 0s 3ms/step - loss: 1.0730 - val_loss: 1.1290
# Epoch 187/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0566 - val_loss: 1.0819
# Epoch 188/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0627 - val_loss: 1.2038
# Epoch 189/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0678 - val_loss: 1.1298
# Epoch 190/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0291 - val_loss: 1.0717
# Epoch 191/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9857 - val_loss: 1.0524
# Epoch 192/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9873 - val_loss: 1.1214
# Epoch 193/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0384 - val_loss: 1.1066
# Epoch 194/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0021 - val_loss: 1.0040
# Epoch 195/200
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0235 - val_loss: 1.0329
# Epoch 196/200
# 67/67 [==============================] - 0s 3ms/step - loss: 0.9565 - val_loss: 1.1018
# Epoch 197/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9947 - val_loss: 1.0548
# Epoch 198/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9355 - val_loss: 1.1349
# Epoch 199/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9208 - val_loss: 0.9748
# Epoch 200/200
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9159 - val_loss: 1.0084

# %%
width = 8
height = width/1.618
plt.figure(figsize=(width, height))

plt.plot(history.history["loss"], label="training")
plt.plot(history.history["val_loss"], label="validation")

plt.xlabel("Epochs")
plt.ylabel("NLL")

plt.legend()

plt.show()

# %% [markdown]
# Let us visualize the learned uncertainty estimates.

# %%
pred_s_ty = model_uq(s_tx)

pred_ty_mean = pred_s_ty.loc.numpy() + scaler_y.mean_
pred_ty_var = np.square(pred_s_ty.scale.numpy()) * scaler_y.var_

width = 8
height = width/1.618
plt.figure(figsize=(width, height))

plt.plot(tx, ty, label="truth")
plt.plot(tx, pred_ty_mean, label="$\mu$")
plt.fill_between(
    tx.reshape(-1), 
    (pred_ty_mean - pred_ty_var).reshape(-1), 
    (pred_ty_mean + pred_ty_var).reshape(-1), 
    color="orange", 
    alpha=0.5,
    label="$\sigma^2$"
)

y_lim = 10
plt.fill_between([-30, -20], [-y_lim, -y_lim], [y_lim, y_lim], color="grey", alpha=0.5)
plt.fill_between([20, 30], [-y_lim, -y_lim], [y_lim, y_lim], color="grey", alpha=0.5)

plt.legend()
plt.ylim(-y_lim, y_lim)

plt.show()

# %% [markdown]
# The learned mean estimates appears to be worse than when minimizing the mean squared error loss. Also, we can see than the variance estimate are not meaningful in areas missing data (white background) and do not learn properly the noise in are with data (grey background).

# %% [markdown]
# ## Ensemble of Reural Networks With Random Initialization
#
# The uncertainty estimate of a single neural network corresponds to aleatoric uncertainty (i.e., intrinsic noise of the data). To estimate the epistemic uncertainty, composed of estimation uncertainty (e.g., optimization algorithm) and model uncertainty (e.g., hypothesis space of models), we need to quantify the variation of predictions for different models and estimation. One of the most basic method to do it is to keep a fixed neural network architecture and training hyperparameters to then re-train it multiple times from different random weight initialization.

# %%
def generate_model(model_id):
    
    # Model
    input_ = tf.keras.layers.Input(shape=(1,))
    out = tf.keras.layers.Dense(200, activation="relu")(input_)
    out = tf.keras.layers.Dense(200, activation="relu")(out)
    out = tf.keras.layers.Dense(2)(out) # 1 unit for the mean, 1 unit for the scale
    output = tfp.layers.DistributionLambda(
                lambda t: tfd.Normal(
                    loc=t[..., :1],
                    scale=1e-3 + tf.math.softplus(0.05 * t[..., 1:]),
                )
            )(out)
    model_uq = tf.keras.Model(input_, output)
    
    
    model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
        filepath=os.path.join("models_random_init", f"{model_id}.h5"), 
        monitor='val_loss', 
        verbose=0, 
        save_best_only=True,
        save_weights_only=False, 
        mode='min', 
        save_freq='epoch'
    )

    optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)
    model_uq.compile(optimizer, loss=nll)

    history = model_uq.fit(s_x, s_y, 
                           epochs=200, 
                           batch_size=4, 
                           validation_data=(s_vx, s_vy), 
                           verbose=0,
                           callbacks=[model_checkpoint_callback]
                          ).history
    return history["val_loss"][-1]

if is_gpu_available:
    generate_model = ray.remote(num_cpus=1, num_gpus=1)(generate_model)
else:
    generate_model = ray.remote(num_cpus=1)(generate_model)

# %% [markdown]
# We generate `n_models` from different random weight initializations. The computation can be distributed on different GPUs or CPU cores if we use Ray `.remote(...)` calls.

# %%
if os.path.exists("models_random_init"):
    shutil.rmtree("models_random_init")
pathlib.Path("models_random_init").mkdir(parents=False, exist_ok=False)

n_models = 10
scores = ray.get([generate_model.remote(model_id) for model_id in range(n_models)])

print(scores)
# Out:
# [1.218247413635254, 0.812317430973053, 0.8843662142753601, 1.2385529279708862, 1.2138310670852661, 1.2532318830490112, 1.222377896308899, 0.9355661273002625, 1.1873416900634766, 0.9032349586486816]

# %% [markdown]
# The `UQBaggingEnsembleRegressor` provides different strategies to build ensemble of neural networks from a library of saved models. The computation is distributed with Ray (for the inference and ranking of ensemble members).

# %%
from deephyper.ensemble import UQBaggingEnsembleRegressor

ensemble = UQBaggingEnsembleRegressor(
    model_dir="models_random_init",
    loss=nll,  # default is nll
    size=5,
    verbose=True,
    ray_address="auto",
    num_cpus=1,
    num_gpus=1 if is_gpu_available else None,
    selection="topk",
)

# %%
# Follow the Scikit-Learn fit/predict interface
ensemble.fit(s_vx, s_vy)

print(f"Selected members are: ", ensemble.members_files)
# Out:
# Selected members are:  ['9.h5', '2.h5', '1.h5', '3.h5', '7.h5']

# %% [markdown]
# We can visualize the uncertainty estimate of such ensemble.

# %%
pred_s_ty, pred_s_ty_aleatoric_var, pred_s_ty_epistemic_var = ensemble.predict_var_decomposition(s_tx)

pred_ty_mean = pred_s_ty.loc.numpy() + scaler_y.mean_
pred_ty_aleatoric_var = pred_s_ty_aleatoric_var * scaler_y.var_
pred_ty_epistemic_var = pred_s_ty_epistemic_var * scaler_y.var_

width = 8
height = width/1.618
plt.figure(figsize=(width, height))

plt.plot(tx, ty, label="truth")
plt.plot(tx, pred_ty_mean, label="$\mu$")
plt.fill_between(
    tx.reshape(-1), 
    (pred_ty_mean - pred_ty_aleatoric_var).reshape(-1), 
    (pred_ty_mean + pred_ty_aleatoric_var).reshape(-1), 
    color="yellow", 
    alpha=0.5,
    label="$E[\sigma^2]$: aleatoric"
)
plt.fill_between(
    tx.reshape(-1), 
    (pred_ty_mean - pred_ty_aleatoric_var).reshape(-1), 
    (pred_ty_mean - pred_ty_aleatoric_var - pred_s_ty_epistemic_var).reshape(-1), 
    color="orange", 
    alpha=0.5,
    label="$V[\mu]$: epistemic"
)
plt.fill_between(
    tx.reshape(-1), 
    (pred_ty_mean + pred_ty_aleatoric_var).reshape(-1), 
    (pred_ty_mean + pred_ty_aleatoric_var + pred_s_ty_epistemic_var).reshape(-1), 
    color="orange", 
    alpha=0.5,
#     label="$V[\mu]$: epistemic"
)

y_lim = 10
plt.fill_between([-30, -20], [-y_lim, -y_lim], [y_lim, y_lim], color="grey", alpha=0.5)
plt.fill_between([20, 30], [-y_lim, -y_lim], [y_lim, y_lim], color="grey", alpha=0.5)

plt.legend()
plt.ylim(-y_lim, y_lim)

plt.show()

# %% [markdown]
# By using the **Law of Total Variance** we can decompose the aleatoric and epistemic components of the predicted uncertainty. With random-initialization we can see that epistemic uncertainty is almost null everywhere and not informative on area missing data (white background).

# %% [markdown]
# ## AutoDEUQ: Automated Deep Ensemble with Uncertainty Quantification
#
# AutoDEUQ is an algorithm in 2 steps:
# 1. joint hyperparameter and neural architecture search to generate a catalog of models.
# 2. build an ensemble from the catalog
#
# To this end we start by editing slightly the previous `RegressionFactory` by adding the `DistributionLambda` layer as output.

# %%
DistributionLambda = operation(tfp.layers.DistributionLambda)

# %%
class RegressionUQFactory(SpaceFactory):
    
    def build(self, input_shape, output_shape, num_layers=3, **kwargs):

        self.ss = KSearchSpace(input_shape, output_shape)

        out_sub_graph = self.build_sub_graph(self.ss.input_nodes[0], num_layers)
        
        output_dim = output_shape[0]
        output_dense = ConstantNode(op=Dense(output_dim*2))  
        self.ss.connect(out_sub_graph, output_dense)
        
        
        output_dist = ConstantNode(
            op=DistributionLambda(
                lambda t: tfd.Normal(
                    loc=t[..., :output_dim],
                    scale=1e-3 + tf.math.softplus(0.05 * t[..., output_dim:]),
                )
            )
        )
        self.ss.connect(output_dense, output_dist)

        return self.ss

    def build_sub_graph(self, input_node, num_layers=3):
        

        # Look over skip connections within a range of the 3 previous nodes
        anchor_points = collections.deque([input_node], maxlen=3)
        
        prev_node = input_node
        
        for _ in range(num_layers):
            
            # Create a variable node to list possible "Dense" layers
            dense = VariableNode()
            
            # Add the possible operations to the dense node
            self.add_dense_to_(dense)
            
            # Connect the previous node to the dense node
            self.ss.connect(prev_node, dense)

            # Create a constant node to merge all input connections
            merge = ConstantNode()
            merge.set_op(
                AddByProjecting(self.ss, [dense], activation="relu")
            )

            for node in anchor_points:
                
                # Create a variable node for each possible connection
                skipco = VariableNode()
                
                skipco.add_op(Zero()) # corresponds to no connection
                skipco.add_op(Connect(self.ss, node)) # corresponds to (node => skipco)
                
                # Connect the (skipco => merge)
                self.ss.connect(skipco, merge)

 
            # ! for next iter
            prev_node = merge
            anchor_points.append(prev_node)

        return prev_node

    def add_dense_to_(self, node):
        
        # We add the "Identity" operation to allow the choice "doing nothing"
        node.add_op(Identity())
        
        step = 16
        for units in range(step, step * 16 + 1, step):
            for activation in ACTIVATIONS:
                node.add_op(Dense(units=units, activation=activation))


def create_search_space_uq(input_shape=(1,), output_shape=(1,), **kwargs):
    return RegressionUQFactory()(input_shape, output_shape, **kwargs)

# %% [markdown]
# For joint hyperparameter and neural architecture search it is possible to use the `problem.add_hyperparameter(...)` to define variable hyperparameters in the NAS Problem.

# %%
problem_uq = NaProblem()

problem_uq.load_data(load_data_train_valid)

problem_uq.preprocessing(stdscaler)

problem_uq.search_space(create_search_space_uq, num_layers=3)

problem_uq.hyperparameters(
    batch_size=problem_uq.add_hyperparameter((1, 32), "batch_size"),
    learning_rate=problem_uq.add_hyperparameter(
        (1e-4, 0.1, "log-uniform"),
        "learning_rate",
    ),
    optimizer=problem_uq.add_hyperparameter(
        ["sgd", "rmsprop", "adagrad", "adam", "adadelta", "adamax", "nadam"],
        "optimizer",
    ),
    patience_ReduceLROnPlateau=problem_uq.add_hyperparameter(
        (10, 20), "patience_ReduceLROnPlateau"
    ),
    patience_EarlyStopping=problem_uq.add_hyperparameter(
        (20, 30), "patience_EarlyStopping"
    ),
    num_epochs=200,
    callbacks=dict(
        ReduceLROnPlateau=dict(monitor="val_loss", mode="min", verbose=0, patience=5),
        EarlyStopping=dict(monitor="val_loss", mode="min", verbose=0, patience=10),
        # We save trained models in neural architecture search
        ModelCheckpoint=dict(
            monitor="val_loss",
            mode="min",
            save_best_only=True,
            verbose=0,
            filepath="model.h5",
            save_weights_only=False,
        ),
    ),
)

problem_uq.loss(nll)

problem_uq.metrics([])

# The objective is maximized so we take the negative of the validation loss
# where the loss is minimized
problem_uq.objective("-val_loss")

problem_uq
# Out:
# Problem is:
#  * SEED = None *
#     - search space   : __main__.create_search_space_uq
#     - data loading   : __main__.load_data_train_valid
#     - preprocessing  : __main__.stdscaler
#     - hyperparameters:
#         * verbose: 0
#         * batch_size: batch_size, Type: UniformInteger, Range: [1, 32], Default: 16
#         * learning_rate: learning_rate, Type: UniformFloat, Range: [0.0001, 0.1], Default: 0.0031622777, on log-scale
#         * optimizer: optimizer, Type: Categorical, Choices: {sgd, rmsprop, adagrad, adam, adadelta, adamax, nadam}, Default: sgd
#         * patience_ReduceLROnPlateau: patience_ReduceLROnPlateau, Type: UniformInteger, Range: [10, 20], Default: 15
#         * patience_EarlyStopping: patience_EarlyStopping, Type: UniformInteger, Range: [20, 30], Default: 25
#         * num_epochs: 200
#         * callbacks: {'ReduceLROnPlateau': {'monitor': 'val_loss', 'mode': 'min', 'verbose': 0, 'patience': 5}, 'EarlyStopping': {'monitor': 'val_loss', 'mode': 'min', 'verbose': 0, 'patience': 10}, 'ModelCheckpoint': {'monitor': 'val_loss', 'mode': 'min', 'save_best_only': True, 'verbose': 0, 'filepath': 'model.h5', 'save_weights_only': False}}
#     - loss           : <function nll at 0x7f7e8cfcedc0>
#     - metrics        :
#     - objective      : -val_loss
#     - post-training  : None

# %%
results_uq = {}

# %% [markdown]
# The `max_evals` has to be superior or equal to 400 to start having a good UQ estimate.

# %%
from deephyper.search.nas.agebo import AgEBO


if os.path.exists("save"):
    shutil.rmtree("save")

# "n_jobs" is the number of processes used to refresh the state of the surrogate model used in AgEBO 
agebo_search = AgEBO(problem_uq, get_evaluator(run_nas), n_jobs=4)

results_uq["agebo"] = agebo_search.search(max_evals=400)

# %%
results_uq["agebo"]

# %% [markdown]
# Different sizes of ensemble and two selection strategies can be experimented for ensembles:
# * `caruana`: a greedy selection from Caruana based on the loss function.
# * `topk`: select the top-k (i.e., `size`) best models based on the loss function.

# %%
ensemble = UQBaggingEnsembleRegressor(
    model_dir="save/model",
    loss=nll,  # default is nll
    size=100,
    verbose=True,
    ray_address="auto",
    num_cpus=1,
    num_gpus=1 if is_gpu_available else None,
    selection="topk",
)

ensemble.fit(s_vx, s_vy)

print(f"Selected {len(ensemble.members_files)} members are: ", ensemble.members_files)
# Out:
# Selected 100 members are:  ['2ad8cfca-21f8-11ec-93e3-ebd61bb8f6c2_30-Sep-2021_09-10-29.h5', '5535cb4e-21f6-11ec-93e3-ebd61bb8f6c2_30-Sep-2021_08-57-21.h5', '042482c2-21fb-11ec-93e3-ebd61bb8f6c2_30-Sep-2021_09-30-53.h5', 'f4bb2c0a-21fa-11ec-93e3-ebd61bb8f6c2_30-Sep-2021_09-30-27.h5', 'ab5b42d4-21fa-11ec-93e3-ebd61bb8f6c2_30-Sep-2021_09-28-24.h5', '5159f8b4-21f7-11ec-93e3-ebd61bb8f6c2_30-Sep-2021_09-04-24.h5', 'ab05ebfc-21f7-11ec-93e3-ebd61bb8f6c2_30-Sep-2021_09-06-55.h5', '0897d542-21f7-11ec-93e3-ebd61bb8f6c2_30-Sep-2021_09-02-22.h5', '5ccfdadc-21f8-11ec-93e3-ebd61bb8f6c2_30-Sep-2021_09-11-53.h5', '7783b6bc-21fa-11ec-93e3-ebd61bb8f6c2_30-Sep-2021_09-26-57.h5', 'f58c42de-21f7-11ec-93e3-ebd61bb8f6c2_30-Sep-2021_09-09-00.h5', '402cb62e-21f9-11ec-93e3-ebd61bb8f6c2_30-Sep-2021_09-18-14.h5', '37cc5b2c-21fb-11ec-93e3-ebd61bb8f6c2_30-Sep-2021_09-32-19.h5', 'd344fb16-21f8-11ec-93e3-ebd61bb8f6c2_30-Sep-2021_09-15-12.h5', '7efea136-21fa-11ec-93e3-ebd61bb8f6c2_30-Sep-2021_09-27-09.h5', '7266d6d2-21fa-11ec-93e3-ebd61bb8f6c2_30-Sep-2021_09-26-48.h5', '0476be6a-21f7-11ec-93e3-ebd61bb8f6c2_30-Sep-2021_09-02-15.h5', '944778de-21f9-11ec-93e3-ebd61bb8f6c2_30-Sep-2021_09-20-35.h5', '734945a2-21fb-11ec-93e3-ebd61bb8f6c2_30-Sep-2021_09-33-59.h5', 'd61bcace-21f6-11ec-93e3-ebd61bb8f6c2_30-Sep-2021_09-00-57.h5', '9b0518f4-21f7-11ec-93e3-ebd61bb8f6c2_30-Sep-2021_09-06-28.h5', 'd3a7f440-21f9-11ec-93e3-ebd61bb8f6c2_30-Sep-2021_09-22-22.h5', '7051f09c-21fb-11ec-93e3-ebd61bb8f6c2_30-Sep-2021_09-33-54.h5', '132cac6e-21fa-11ec-93e3-ebd61bb8f6c2_30-Sep-2021_09-24-08.h5', '74620fda-21f8-11ec-93e3-ebd61bb8f6c2_30-Sep-2021_09-12-32.h5', 'f7455b68-21f9-11ec-93e3-ebd61bb8f6c2_30-Sep-2021_09-23-22.h5', '1573fd2e-21fa-11ec-93e3-ebd61bb8f6c2_30-Sep-2021_09-24-12.h5', '582e352c-21f9-11ec-93e3-ebd61bb8f6c2_30-Sep-2021_09-18-55.h5', 'd732e48e-21fa-11ec-93e3-ebd61bb8f6c2_30-Sep-2021_09-29-37.h5', '802d4544-21fa-11ec-93e3-ebd61bb8f6c2_30-Sep-2021_09-27-11.h5', '82db04d0-21f9-11ec-93e3-ebd61bb8f6c2_30-Sep-2021_09-20-06.h5', '86c8aaac-21f9-11ec-93e3-ebd61bb8f6c2_30-Sep-2021_09-20-13.h5', '7cae8884-21f9-11ec-93e3-ebd61bb8f6c2_30-Sep-2021_09-19-56.h5', 'bc31286e-21f8-11ec-93e3-ebd61bb8f6c2_30-Sep-2021_09-14-33.h5', '260d7ddc-21f9-11ec-93e3-ebd61bb8f6c2_30-Sep-2021_09-17-31.h5', '48073e0a-21f9-11ec-93e3-ebd61bb8f6c2_30-Sep-2021_09-18-28.h5', '064e0252-21f7-11ec-93e3-ebd61bb8f6c2_30-Sep-2021_09-02-18.h5', '5e94a39a-21fb-11ec-93e3-ebd61bb8f6c2_30-Sep-2021_09-33-24.h5', '26bc754a-21f8-11ec-93e3-ebd61bb8f6c2_30-Sep-2021_09-10-22.h5', '24b3b422-21fb-11ec-93e3-ebd61bb8f6c2_30-Sep-2021_09-31-47.h5', '2a595c74-21f6-11ec-93e3-ebd61bb8f6c2_30-Sep-2021_08-56-09.h5', 'a8a93672-21fa-11ec-93e3-ebd61bb8f6c2_30-Sep-2021_09-28-19.h5', '7632675c-21f7-11ec-93e3-ebd61bb8f6c2_30-Sep-2021_09-05-26.h5', '4aa98c42-21fb-11ec-93e3-ebd61bb8f6c2_30-Sep-2021_09-32-51.h5', 'd17558f6-21fa-11ec-93e3-ebd61bb8f6c2_30-Sep-2021_09-29-28.h5', '04b54a22-21f7-11ec-93e3-ebd61bb8f6c2_30-Sep-2021_09-02-16.h5', '47c218c2-21f7-11ec-93e3-ebd61bb8f6c2_30-Sep-2021_09-04-08.h5', '23db1a78-21fa-11ec-93e3-ebd61bb8f6c2_30-Sep-2021_09-24-36.h5', '537feada-21f8-11ec-93e3-ebd61bb8f6c2_30-Sep-2021_09-11-37.h5', '1138e638-21f6-11ec-93e3-ebd61bb8f6c2_30-Sep-2021_08-55-27.h5', 'd473b582-21f7-11ec-93e3-ebd61bb8f6c2_30-Sep-2021_09-08-04.h5', 'dc8ddf44-21f8-11ec-93e3-ebd61bb8f6c2_30-Sep-2021_09-15-27.h5', '37fcbef6-21f7-11ec-93e3-ebd61bb8f6c2_30-Sep-2021_09-03-42.h5', '2f56f268-21f6-11ec-93e3-ebd61bb8f6c2_30-Sep-2021_08-56-18.h5', '761073f6-21fa-11ec-93e3-ebd61bb8f6c2_30-Sep-2021_09-26-54.h5', '38cbcb02-21fb-11ec-93e3-ebd61bb8f6c2_30-Sep-2021_09-32-21.h5', 'e14a7e0c-21f8-11ec-93e3-ebd61bb8f6c2_30-Sep-2021_09-15-35.h5', '6cfc0e32-21fb-11ec-93e3-ebd61bb8f6c2_30-Sep-2021_09-33-49.h5', '049880a4-21f7-11ec-93e3-ebd61bb8f6c2_30-Sep-2021_09-02-15.h5', '6277d59a-21fb-11ec-93e3-ebd61bb8f6c2_30-Sep-2021_09-33-31.h5', '0a9ec586-21fb-11ec-93e3-ebd61bb8f6c2_30-Sep-2021_09-31-04.h5', '4a4db1fc-21fa-11ec-93e3-ebd61bb8f6c2_30-Sep-2021_09-25-41.h5', 'b17 ...

# %%
pred_s_ty, pred_s_ty_aleatoric_var, pred_s_ty_epistemic_var = ensemble.predict_var_decomposition(s_tx)

pred_ty_mean = pred_s_ty.loc.numpy() + scaler_y.mean_
pred_ty_aleatoric_var = pred_s_ty_aleatoric_var * scaler_y.var_
pred_ty_epistemic_var = pred_s_ty_epistemic_var * scaler_y.var_

width = 8
height = width/1.618
plt.figure(figsize=(width, height))

plt.plot(tx, ty, label="truth")
plt.plot(tx, pred_ty_mean, label="$\mu$")
plt.fill_between(
    tx.reshape(-1), 
    (pred_ty_mean - pred_ty_aleatoric_var).reshape(-1), 
    (pred_ty_mean + pred_ty_aleatoric_var).reshape(-1), 
    color="yellow", 
    alpha=0.5,
    label="$E[\sigma^2]$: aleatoric"
)
plt.fill_between(
    tx.reshape(-1), 
    (pred_ty_mean - pred_ty_aleatoric_var).reshape(-1), 
    (pred_ty_mean - pred_ty_aleatoric_var - pred_s_ty_epistemic_var).reshape(-1), 
    color="orange", 
    alpha=0.5,
    label="$V[\mu]$: epistemic"
)
plt.fill_between(
    tx.reshape(-1), 
    (pred_ty_mean + pred_ty_aleatoric_var).reshape(-1), 
    (pred_ty_mean + pred_ty_aleatoric_var + pred_s_ty_epistemic_var).reshape(-1), 
    color="orange", 
    alpha=0.5,
)

y_lim = 10
plt.fill_between([-30, -20], [-y_lim, -y_lim], [y_lim, y_lim], color="grey", alpha=0.5)
plt.fill_between([20, 30], [-y_lim, -y_lim], [y_lim, y_lim], color="grey", alpha=0.5)

plt.legend()
plt.ylim(-y_lim, y_lim)

plt.show()

# %% [markdown]
# We notice that adding more diversity in the catalog can help have much better epistemic uncertainty estimates.
